# %% [markdown]
# # Tune GPT2 to generate positive reviews
# > Optimise GPT2 to produce positive IMDB movie reviews using a BERT sentiment classifier for rewards.

# %% [markdown]
# <div style="text-align: center">
# <img src='images/gpt2_bert_training.png' width='600'>
# <p style="text-align: center;"> <b>Figure:</b> Experiment setup to tune GPT2. The yellow arrows are outside the scope of this notebook, but the trained models are available through Hugging Face. </p>
# </div>
#
#
# In this notebook we fine-tune GPT2 (small) to generate positive movie reviews based on the IMDB dataset. The model gets 5 tokens from a real review and is tasked to produce positive continuations. To reward positive continuations we use a BERT classifier to analyse the sentiment of the produced sentences and use the classifier's outputs as rewards signals for PPO training.

# %% [markdown]
# ## Setup experiment

# %% [markdown]
# ### Import dependencies

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# [autoreload of transformers failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.albert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.auto failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.bart failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.barthez failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.bert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.bert_generation failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.bert_japanese failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.bertweet failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.blenderbot failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.blenderbot_small failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.camembert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.convbert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.ctrl failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.deberta failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.distilbert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.dpr failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.electra failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.encoder_decoder failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.flaubert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.fsmt failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.funnel failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.gpt2 failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.herbert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of tokenizers.models failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 855, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/tokenizers/models/__init__.py", line 4, in <module>
#     Model = models.Model
# AttributeError: module 'tokenizers.models' has no attribute 'Model'
# ]
# [autoreload of tokenizers.normalizers failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 855, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/tokenizers/normalizers/__init__.py", line 3, in <module>
#     Normalizer = normalizers.Normalizer
# AttributeError: module 'tokenizers.normalizers' has no attribute 'Normalizer'
# ]
# [autoreload of tokenizers.pre_tokenizers failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 855, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/tokenizers/pre_tokenizers/__init__.py", line 4, in <module>
#     PreTokenizer = pre_tokenizers.PreTokenizer
# AttributeError: module 'tokenizers.pre_tokenizers' has no attribute 'PreTokenizer'
# ]
# [autoreload of tokenizers.processors failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 855, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/tokenizers/processors/__init__.py", line 4, in <module>
#     PostProcessor = processors.PostProcessor
# AttributeError: module 'tokenizers.processors' has no attribute 'PostProcessor'
# ]
# [autoreload of tokenizers.decoders failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 855, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/tokenizers/decoders/__init__.py", line 3, in <module>
#     Decoder = decoders.Decoder
# AttributeError: module 'tokenizers.decoders' has no attribute 'Decoder'
# ]
# [autoreload of transformers.tokenization_utils failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 480, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 329, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 289, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_special_tokens_mask() requires a code object with 1 free vars, not 0
# ]
# [autoreload of transformers.models.bert.tokenization_bert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 480, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 329, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 289, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_special_tokens_mask() requires a code object with 1 free vars, not 0
# ]
# [autoreload of transformers.models.layoutlm failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.led failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.longformer failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.lxmert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.marian failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.mbart failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.mmbt failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.mobilebert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.mpnet failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.t5 failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.t5.tokenization_t5 failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 480, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 329, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 289, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_special_tokens_mask() requires a code object with 1 free vars, not 0
# ]
# [autoreload of transformers.models.t5.tokenization_t5_fast failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 480, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 329, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 329, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 289, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_special_tokens_mask() requires a code object with 1 free vars, not 0
# ]
# [autoreload of transformers.models.mt5 failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.openai failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.pegasus failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.phobert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.prophetnet failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.rag failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.reformer failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.retribert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.roberta failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.squeezebert failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.tapas failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.transfo_xl failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.wav2vec2 failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.xlm failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.xlm_prophetnet failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.xlm_roberta failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.xlnet failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/home/wzm289/miniconda3/lib/python3.9/importlib/__init__.py", line 142, in reload
#     name = module.__spec__.name
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/transformers/file_utils.py", line 2689, in __getattr__
#   [Previous line repeated 4 more times]
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of transformers.models.auto.modeling_auto failed: Traceback (most recent call last):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 480, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 329, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 368, in <lambda>
#     lambda a, b: update_function(a.__func__, b.__func__),
#   File "/home/wzm289/miniconda3/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 289, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: from_config() requires a code object with 1 free vars, not 0
# ]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
import wandb
import time
import os
from tqdm import tqdm
import numpy as np
import pandas as pd
tqdm.pandas()

from datasets import load_dataset

from transformers import GPT2Tokenizer
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from trl.gpt2 import GPT2HeadWithValueModel, respond_to_batch
from trl.ppo import PPOTrainer
from trl.core import build_bert_batch_from_txt

# %% [markdown]
# ### Configuration

# %%
config = {
    "lm_name": "lvwerra/gpt2-imdb",
    "ref_lm_name": "lvwerra/gpt2-imdb",
    "cls_model_name": "lvwerra/distilbert-imdb",
    "tk_name": "gpt2",
    "steps": 25600,
    "batch_size": 256,
    "forward_batch_size": 16,
    "ppo_epochs": 4,   
    "txt_in_len": 5,
    "txt_out_len": 15,
    "lr": 1.41e-5,
    "init_kl_coef":0.2,
    "target": 6,
    "horizon":10000,
    "gamma":1,
    "lam":0.95,
    "cliprange": .2,
    "cliprange_value":.2,
    "vf_coef":.1, 
}

# %% [markdown]
# You can see that we load a GPT2 model called `gpt2_imdb`. This model was additionally fine-tuned on the IMDB dataset for 1 epoch with the huggingface [script](https://github.com/huggingface/transformers/blob/master/examples/run_language_modeling.py) (no special settings). The other parameters are mostly taken from the original paper ["Fine-Tuning Language Models from Human Preferences"](
# https://arxiv.org/pdf/1909.08593.pdf). This model as well as the BERT model is available in the Huggingface model zoo [here](https://huggingface.co/models). The following code should automatically download the models.

# %% [markdown]
# ### Initialize W&B logger
# We use `wandb`to log all the metrics during training.

# %%
wandb.init(name='run-42', project='gpt2-sentiment', config=config, )
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Appending key for api.wandb.ai to your netrc file: /home/wzm289/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/zhansu/gpt2-sentiment/runs/2i72vyve" target="_blank">run-42</a></strong> to <a href="https://wandb.ai/zhansu/gpt2-sentiment" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/zhansu/gpt2-sentiment/runs/2i72vyve?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %% [markdown]
# ## Load data and models

# %% [markdown]
# ### Load IMDB dataset
# The IMDB dataset contains 50k movie review annotated with "positive"/"negative" feedback indicating the sentiment.  We load the IMDB dataset into a DataFrame and filter for comments that are at least 500 characters long and take the first 1000 characters of each comment. The first filter we apply to avoid comments that are less than `txt_in_len` token long and the second to avoid tokenizing way more text than we actually need.

# %%
# load imdb with datasets
ds = load_dataset('imdb', split='train')
ds = ds.rename_columns({'text': 'review', 'label': 'sentiment'})
ds.set_format('pandas')
df = ds[:]

# make sure the comments are long enough
df = df.loc[df['review'].str.len() > 500]

# make sure comments are not too long
df['review'] = df['review'].apply(lambda x: x[:1000])

df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /projects/futhark1/data/wzm289/code/trl/nbs/04-gpt2-sentiment-ppo-training.ipynb Cell 14' in <module>
#       <a href='vscode-notebook-cell://ssh-remote%2Bfutharkhpa01fl.unicph.domain/projects/futhark1/data/wzm289/code/trl/nbs/04-gpt2-sentiment-ppo-training.ipynb#ch0000013vscode-remote?line=0'>1</a> # load imdb with datasets
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bfutharkhpa01fl.unicph.domain/projects/futhark1/data/wzm289/code/trl/nbs/04-gpt2-sentiment-ppo-training.ipynb#ch0000013vscode-remote?line=1'>2</a> ds = load_dataset('imdb', split='train')
#       <a href='vscode-notebook-cell://ssh-remote%2Bfutharkhpa01fl.unicph.domain/projects/futhark1/data/wzm289/code/trl/nbs/04-gpt2-sentiment-ppo-training.ipynb#ch0000013vscode-remote?line=2'>3</a> ds = ds.rename_columns({'text': 'review', 'label': 'sentiment'})
#       <a href='vscode-notebook-cell://ssh-remote%2Bfutharkhpa01fl.unicph.domain/projects/futhark1/data/wzm289/code/trl/nbs/04-gpt2-sentiment-ppo-training.ipynb#ch0000013vscode-remote?line=3'>4</a> ds.set_format('pandas')
#
# File ~/miniconda3/lib/python3.9/site-packages/datasets/load.py:1675, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, script_version, **config_kwargs)
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1671'>1672</a> ignore_verifications = ignore_verifications or save_infos
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1673'>1674</a> # Create a dataset builder
# -> <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1674'>1675</a> builder_instance = load_dataset_builder(
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1675'>1676</a>     path=path,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1676'>1677</a>     name=name,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1677'>1678</a>     data_dir=data_dir,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1678'>1679</a>     data_files=data_files,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1679'>1680</a>     cache_dir=cache_dir,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1680'>1681</a>     features=features,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1681'>1682</a>     download_config=download_config,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1682'>1683</a>     download_mode=download_mode,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1683'>1684</a>     revision=revision,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1684'>1685</a>     use_auth_token=use_auth_token,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1685'>1686</a>     **config_kwargs,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1686'>1687</a> )
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1688'>1689</a> # Return iterable dataset in case of streaming
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1689'>1690</a> if streaming:
#
# File ~/miniconda3/lib/python3.9/site-packages/datasets/load.py:1512, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, use_auth_token, script_version, **config_kwargs)
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1509'>1510</a>     download_config = download_config.copy() if download_config else DownloadConfig()
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1510'>1511</a>     download_config.use_auth_token = use_auth_token
# -> <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1511'>1512</a> dataset_module = dataset_module_factory(
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1512'>1513</a>     path, revision=revision, download_config=download_config, download_mode=download_mode, data_files=data_files
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1513'>1514</a> )
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1515'>1516</a> # Get dataset builder class from the processing script
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1516'>1517</a> builder_cls = import_main_class(dataset_module.module_path)
#
# File ~/miniconda3/lib/python3.9/site-packages/datasets/load.py:1203, in dataset_module_factory(path, revision, download_config, download_mode, force_local_path, dynamic_modules_path, data_files, **download_kwargs)
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1197'>1198</a>             if isinstance(e1, FileNotFoundError):
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1198'>1199</a>                 raise FileNotFoundError(
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1199'>1200</a>                     f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory. "
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1200'>1201</a>                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1201'>1202</a>                 ) from None
# -> <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1202'>1203</a>             raise e1 from None
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1203'>1204</a> else:
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1204'>1205</a>     raise FileNotFoundError(
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1205'>1206</a>         f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory."
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1206'>1207</a>     )
#
# File ~/miniconda3/lib/python3.9/site-packages/datasets/load.py:1141, in dataset_module_factory(path, revision, download_config, download_mode, force_local_path, dynamic_modules_path, data_files, **download_kwargs)
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1138'>1139</a> _raise_if_offline_mode_is_enabled()
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1139'>1140</a> if path.count("/") == 0:  # canonical datasets/metrics: github path
# -> <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1140'>1141</a>     return CanonicalDatasetModuleFactory(
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1141'>1142</a>         path,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1142'>1143</a>         revision=revision,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1143'>1144</a>         download_config=download_config,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1144'>1145</a>         download_mode=download_mode,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1145'>1146</a>         dynamic_modules_path=dynamic_modules_path,
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1146'>1147</a>     ).get_module()
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1147'>1148</a> elif path.count("/") == 1:  # users datasets/metrics: s3 path (hub for datasets and s3 for metrics)
#    <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=1148'>1149</a>     hf_api = HfApi(config.HF_ENDPOINT)
#
# File ~/miniconda3/lib/python3.9/site-packages/datasets/load.py:522, in CanonicalDatasetModuleFactory.get_module(self)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=519'>520</a> revision = self.revision
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=520'>521</a> try:
# --> <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=521'>522</a>     local_path = self.download_loading_script(revision)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=522'>523</a> except FileNotFoundError:
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=523'>524</a>     if revision is not None or os.getenv("HF_SCRIPTS_VERSION", None) is not None:
#
# File ~/miniconda3/lib/python3.9/site-packages/datasets/load.py:505, in CanonicalDatasetModuleFactory.download_loading_script(self, revision)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=502'>503</a> def download_loading_script(self, revision: Optional[str]) -> str:
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=503'>504</a>     file_path = hf_github_url(path=self.name, name=self.name + ".py", revision=revision)
# --> <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/load.py?line=504'>505</a>     return cached_path(file_path, download_config=self.download_config)
#
# File ~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py:298, in cached_path(url_or_filename, download_config, **download_kwargs)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=293'>294</a>     url_or_filename = str(url_or_filename)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=295'>296</a> if is_remote_url(url_or_filename):
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=296'>297</a>     # URL, so get it from the cache (downloading if necessary)
# --> <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=297'>298</a>     output_path = get_from_cache(
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=298'>299</a>         url_or_filename,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=299'>300</a>         cache_dir=cache_dir,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=300'>301</a>         force_download=download_config.force_download,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=301'>302</a>         proxies=download_config.proxies,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=302'>303</a>         resume_download=download_config.resume_download,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=303'>304</a>         user_agent=download_config.user_agent,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=304'>305</a>         local_files_only=download_config.local_files_only,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=305'>306</a>         use_etag=download_config.use_etag,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=306'>307</a>         max_retries=download_config.max_retries,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=307'>308</a>         use_auth_token=download_config.use_auth_token,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=308'>309</a>         ignore_url_params=download_config.ignore_url_params,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=309'>310</a>     )
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=310'>311</a> elif os.path.exists(url_or_filename):
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=311'>312</a>     # File, and it exists.
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=312'>313</a>     output_path = url_or_filename
#
# File ~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py:659, in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, local_files_only, use_etag, max_retries, use_auth_token, ignore_url_params)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=656'>657</a>         ftp_get(url, temp_file)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=657'>658</a>     else:
# --> <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=658'>659</a>         http_get(
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=659'>660</a>             url,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=660'>661</a>             temp_file,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=661'>662</a>             proxies=proxies,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=662'>663</a>             resume_size=resume_size,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=663'>664</a>             headers=headers,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=664'>665</a>             cookies=cookies,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=665'>666</a>             max_retries=max_retries,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=666'>667</a>         )
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=668'>669</a> logger.info(f"storing {url} in cache at {cache_path}")
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=669'>670</a> shutil.move(temp_file.name, cache_path)
#
# File ~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py:456, in http_get(url, temp_file, proxies, resume_size, headers, cookies, timeout, max_retries)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=453'>454</a> content_length = response.headers.get("Content-Length")
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=454'>455</a> total = resume_size + int(content_length) if content_length is not None else None
# --> <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=455'>456</a> progress = utils.tqdm(
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=456'>457</a>     unit="B",
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=457'>458</a>     unit_scale=True,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=458'>459</a>     total=total,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=459'>460</a>     initial=resume_size,
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=460'>461</a>     desc="Downloading",
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=461'>462</a>     disable=bool(logging.get_verbosity() == logging.NOTSET),
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=462'>463</a> )
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=463'>464</a> for chunk in response.iter_content(chunk_size=1024):
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/file_utils.py?line=464'>465</a>     if chunk:  # filter out keep-alive new chunks
#
# File ~/miniconda3/lib/python3.9/site-packages/datasets/utils/tqdm_utils.py:53, in _tqdm_cls.__call__(self, *args, **kwargs)
#      <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/tqdm_utils.py?line=50'>51</a> def __call__(self, *args, **kwargs):
#      <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/tqdm_utils.py?line=51'>52</a>     if _active:
# ---> <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/tqdm_utils.py?line=52'>53</a>         return tqdm_lib.tqdm(*args, **kwargs)
#      <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/tqdm_utils.py?line=53'>54</a>     else:
#      <a href='file:///~/miniconda3/lib/python3.9/site-packages/datasets/utils/tqdm_utils.py?line=54'>55</a>         return EmptyTqdm(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py:242, in tqdm_notebook.__init__(self, *args, **kwargs)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=239'>240</a> unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=240'>241</a> total = self.total * unit_scale if self.total else self.total
# --> <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=241'>242</a> self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=242'>243</a> self.container.pbar = proxy(self)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=243'>244</a> self.displayed = False
#
# File ~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py:115, in tqdm_notebook.status_printer(_, total, desc, ncols)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=105'>106</a> # Fallback to text bar if there's no total
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=106'>107</a> # DEPRECATED: replaced with an 'info' style bar
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=107'>108</a> # if not total:
#    (...)
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=111'>112</a>
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=112'>113</a> # Prepare IPython progress bar
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=113'>114</a> if IProgress is None:  # #187 #451 #558 #872
# --> <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=114'>115</a>     raise ImportError(
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=115'>116</a>         "IProgress not found. Please update jupyter and ipywidgets."
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=116'>117</a>         " See https://ipywidgets.readthedocs.io/en/stable"
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=117'>118</a>         "/user_install.html")
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=118'>119</a> if total:
#     <a href='file:///~/miniconda3/lib/python3.9/site-packages/tqdm/notebook.py?line=119'>120</a>     pbar = IProgress(min=0, max=total)
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# ### Load BERT classifier
# We load a BERT classifier fine-tuned on the IMDB dataset.

# %%
sentiment_model = AutoModelForSequenceClassification.from_pretrained(config["cls_model_name"])
sentiment_tokenizer = AutoTokenizer.from_pretrained(config["cls_model_name"])

# %% [markdown]
# The model outputs are the logits for the negative and positive class. We will use the logits for positive class as a reward signal for the language model.

# %%
text = 'this movie was really bad!!'
output = sentiment_model.forward(**sentiment_tokenizer(text, return_tensors="pt"))
output
# Out:
# SequenceClassifierOutput(loss=None, logits=tensor([[ 2.3350, -2.7266]], grad_fn=<AddmmBackward0>), hidden_states=None, attentions=None)

# %%
text = 'this movie was really good!!'
output = sentiment_model.forward(**sentiment_tokenizer(text, return_tensors="pt"))
output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /projects/futhark1/data/wzm289/code/trl/nbs/04-gpt2-sentiment-ppo-training.ipynb Cell 19' in <module>
#       <a href='vscode-notebook-cell://ssh-remote%2Bfutharkhpa01fl.unicph.domain/projects/futhark1/data/wzm289/code/trl/nbs/04-gpt2-sentiment-ppo-training.ipynb#ch0000018vscode-remote?line=0'>1</a> text = 'this movie was really good!!'
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bfutharkhpa01fl.unicph.domain/projects/futhark1/data/wzm289/code/trl/nbs/04-gpt2-sentiment-ppo-training.ipynb#ch0000018vscode-remote?line=1'>2</a> output = sentiment_model.forward(**sentiment_tokenizer(text, return_tensors="pt"))
#       <a href='vscode-notebook-cell://ssh-remote%2Bfutharkhpa01fl.unicph.domain/projects/futhark1/data/wzm289/code/trl/nbs/04-gpt2-sentiment-ppo-training.ipynb#ch0000018vscode-remote?line=2'>3</a> output
#
# NameError: name 'sentiment_model' is not defined

# %% [markdown]
# The resulting reward signal:

# %%
output.logits[0, 1]
# Out:
# tensor(2.5570, grad_fn=<SelectBackward0>)

# %% [markdown]
# ### Load pre-trained GPT2 language models

# %% [markdown]
# We load the GPT2 model with a value head and the tokenizer. We load the model twice; the first model is optimized while the second model serves as a reference to calculate the KL-divergence from the starting point. This serves as an additional reward signal in the PPO training to make sure the optimized model does not deviate too much from the original language model.

# %%
gpt2_model = GPT2HeadWithValueModel.from_pretrained(config['lm_name'])
gpt2_model_ref = GPT2HeadWithValueModel.from_pretrained(config['ref_lm_name'])
gpt2_tokenizer = GPT2Tokenizer.from_pretrained(config['tk_name'])

# %% [markdown]
# ### Watch model with wandb
# This wandb magic logs the gradients and weights of the model during training.

# %%
wandb.watch(gpt2_model, log='all')

# %% [markdown]
# ### Move models to GPU

# %% [markdown]
# If `cuda` is available move the computations to the GPU.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
_ = gpt2_model.to(device)
_ = sentiment_model.to(device)
_ = gpt2_model_ref.to(device)

# %% [markdown]
# ### Tokenize IMDB reviews

# %% [markdown]
# We tokenize all IMDB in advance to avoid tokenizing twice. In the first step we encode the queries and slice the first `txt_in_len` tokens. In a second step we decode these tokens back to text for later display.

# %%
df['tokens'] = df['review'].progress_apply(lambda x: gpt2_tokenizer.encode(x, return_tensors="pt").to(device)[0, :config['txt_in_len']])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22578/22578 [00:21<00:00, 1054.55it/s]

# %%
df['query'] = df['tokens'].progress_apply(lambda x: gpt2_tokenizer.decode(x))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 22578/22578 [00:00<00:00, 93906.80it/s]

# %% [markdown]
# ## Optimize model

# %% [markdown]
# **Steps**
#
# The training loop consists of the following steps:
# 1. Get a batch of queries
# 2. Get the query responses from the policy
# 3. Join query and responses and tokenize for BERT analysis
# 4. Get sentiments for query/responses from BERT
# 5. Optimize policy with PPO using the (query, response, reward) triplet
# 6. Log all the training statistics
#
# **Forward batching**
#
# Since the models can be fairly big and we want to rollout large PPO batches this can lead to out-of-memory errors when doing the forward passes for text generation and sentiment analysis. We introduce the parameter `forward_batch_size` to split the forward passes into smaller batches. Although this hurts performance a little this is neglectible compared to the computations of the backward passes when optimizing the model. The same parameter is used in the `PPOTrainer` when doing forward passes. The `batch_size` should multiple of `forward_batch_size`.
#
# **Training time**
#
# This step takes **~2h** on a P6000 GPU with the above specified settings.

# %%
ppo_trainer = PPOTrainer(gpt2_model, gpt2_model_ref, **config)
fbs = config['forward_batch_size']

for epoch in tqdm(range(int(np.ceil(config["steps"]/config['batch_size'])))):
    torch.cuda.empty_cache()
    logs = dict()
    game_data = dict()
    timing = dict()
    t0 = time.time()
    
    #### get a batch from the dataset
    df_batch = df.sample(config['batch_size'])
    game_data['query'] = df_batch['query'].tolist()
    query_tensors = torch.stack(df_batch['tokens'].tolist())
    
    #### get response from gpt2
    t = time.time()
    total_length = config['txt_in_len']+config['txt_out_len']
    response_tensors = []
    for i in range(int(config['batch_size']/fbs)):
        response  = respond_to_batch(gpt2_model, query_tensors[i*fbs:(i+1)*fbs],
                                     txt_len=config['txt_out_len'])
        response_tensors.append(response)
    response_tensors = torch.cat(response_tensors)
    game_data['response'] = [gpt2_tokenizer.decode(response_tensors[i, :]) for i in range(config['batch_size'])]
    timing['time/get_response'] = time.time()-t

    #### tokenize text for sentiment analysis
    t = time.time()
    texts = [q + r for q,r in zip(game_data['query'], game_data['response'])]
    sentiment_inputs, attention_masks = build_bert_batch_from_txt(texts, sentiment_tokenizer, device)    
    timing['time/build_input_sentiment'] = time.time()-t

    #### get sentiment score
    t = time.time()
    rewards = []
    for i in range(int(config['batch_size']/fbs)):
        res = sentiment_model.forward(sentiment_inputs[i*fbs:(i+1)*fbs],
                                      attention_masks[i*fbs:(i+1)*fbs])[0][:, 1].detach()
        rewards.append(res)
    rewards = torch.cat(rewards)
    timing['time/get_sentiment_preds'] = time.time()-t
    
    #### Run PPO training 
    t = time.time()
    stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
    timing['time/optimization'] = time.time()-t
     
    #### Log everything
    timing['time/epoch'] = time.time()-t0
    table_rows = [list(r) for r in zip(game_data['query'], game_data['response'], rewards.cpu().tolist())]
    logs.update({'game_log':wandb.Table(
        columns=['query', 'response', 'reward'],
        rows=table_rows)})
    logs.update(timing)
    logs.update(stats)
    logs['env/reward_mean'] = torch.mean(rewards).cpu().numpy()
    logs['env/reward_std'] = torch.std(rewards).cpu().numpy()
    logs['env/reward_dist'] = rewards.cpu().numpy()
    wandb.log(logs)
# Out:
# wandb: Network error (ConnectionError), entering retry loop. See wandb/debug-internal.log for full traceback.
# wandb: Network error resolved after 1:13:45.556307, resuming normal operation.

# %% [markdown]
# ### Training progress
# If you are tracking the training progress with Weights&Biases you should see a plot similar to the one below. Check out the interactive sample report on wandb.ai: [link](https://app.wandb.ai/lvwerra/trl-showcase/runs/1jtvxb1m/).
#
# <div style="text-align: center">
# <img src='images/gpt2_tuning_progress.png' width='800'>
# <p style="text-align: center;"> <b>Figure:</b> Reward mean and distribution evolution during training. </p>
# </div>
#
# One can observe how the model starts to generate more positive outputs after a few optimisation steps.
#
# > Note: Investigating the KL-divergence will probably show that at this point the model has not converged to the target KL-divergence, yet. To get there would require longer training or starting with a higher inital coefficient.

# %% [markdown]
# ## Model inspection
# Let's inspect some examples from the IMDB dataset. We can use `gpt2_model_ref` to compare the tuned model `gpt2_model` against the model before optimisation.

# %%
#### get a batch from the dataset
bs = 16
game_data = dict()
df_batch = df.sample(bs)
game_data['query'] = df_batch['query'].tolist()
query_tensors = torch.stack(df_batch['tokens'].tolist())

#### get response from gpt2 and gpt2_ref
total_length = config['txt_in_len']+config['txt_out_len']
response_tensors_ref  = respond_to_batch(gpt2_model_ref, query_tensors, txt_len=config['txt_out_len'])
game_data['response (before)'] = [gpt2_tokenizer.decode(response_tensors_ref[i, :]) for i in range(bs)]

response_tensors  = respond_to_batch(gpt2_model, query_tensors, txt_len=config['txt_out_len'])
game_data['response (after)'] = [gpt2_tokenizer.decode(response_tensors[i, :]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q,r in zip(game_data['query'], game_data['response (before)'])]
sentiment_inputs, attention_masks = build_bert_batch_from_txt(texts, sentiment_tokenizer, device)    
rewards = sentiment_model.forward(sentiment_inputs, attention_masks)[0][:, 1].detach()
game_data['rewards (before)'] = rewards.cpu().numpy()

texts = [q + r for q,r in zip(game_data['query'], game_data['response (after)'])]
sentiment_inputs, attention_masks = build_bert_batch_from_txt(texts, sentiment_tokenizer, device)    
rewards = sentiment_model.forward(sentiment_inputs, attention_masks)[0][:, 1].detach()
game_data['rewards (after)'] = rewards.cpu().numpy()

# store results in a dataframe
df_results = pd.DataFrame(game_data)
df_results
# Out:
#                         query  \
# 0       That's what the title
# 1   The female hot numbers on
# 2         In the film Kongwon
# 3             Let's see: what
# 4   Really? Is this necessary
# 5    During a sleepless night
# 6   My wife spotted this film
# 7          I love John's work
# 8          I's a big struggle
# 9         i liked this film a
# 10           I'd never seen a
# 11       I have to agree with
# 12  The only reason I watched
# 13          When I think of a
# 14    So first things first..
# 15       ...this one just isn
#
#                                     response (before)  \
# 0    said to me. All I had to do was hear one word...
# 1    the Fonda get a saving grace here, you can st...
# 2    (American Truffaut), a snake made of ash fall...
# 3    a blast from start to finish, female and male...
# 4    for Sith philosophy combined with missionary ...
# 5    Keira Knightley has besieged a monastery, tro...
# 6    almost halfway through second grade, and afte...
# 7    but I actually have to write language as in w...
# 8    to see anyone who acts in that way. by Jim Th...
# 9    lot Paul Verhoeven The other actor does what ...
# 10   heavier, woodier example of Victorian archite...
# 11   most people, that Davis was right after all. ...
# 12   it this soon after was because part of it too...
# 13   film directed by two independent directors, c...
# 14  blank moment. The montage has the mocking tone...
# 15  't theretonally. I understand the enterprise a...
#
#                                      response (after)  rewards (before)  \
# 0    says, and this movie was very good,-I really ...          1.710360
# 1    the DVD are beautiful. The music is extraordi...          1.585194
# 2    has a funky personality and makes the movies ...         -0.015413
# 3    happens on that later?<|endoftext|> This film...          3.278678
# 4   ? Watched this too, but it's what made it so b...         -2.509291
# 5   , I found this Parker Bros. film. The acting i...          1.341672
# 6          when I was younger and kept her P-1-her-p-          1.781651
# 7    and I hereby recommend this film. I am really...         -1.904006
# 8   , but overall I'm happy with the changes even ...         -1.595925
# 9    lot recipe. It was probably one of the best m...          4.314877
# 10   film of this caliber, and I think it's wonder...          3.297736
# 11   this movie, the features in this film are fan...          0.609289
# 12   this movie I really do. It helps a little to ...         -2.684667
# 13   movie, or potentially a comedy in an interest...         -1.889202
# 14   but first we are really surprised when it sho...         -1.846089
# 15  't really in, after seeing it. I just love it ...         -2.095725
#
#     rewards (after)
# 0          4.207656
# 1          4.228330
# 2          2.537073
# 3          4.061680
# 4          3.025524
# 5          3.933312
# 6          1.456647
# 7          4.159198
# 8          2.651260
# 9          4.346435
# 10         4.158653
# 11         4.207779
# 12        -2.928670
# 13         2.494266
# 14         2.433687
# 15         4.127057

# %% [markdown]
# Looking at the reward mean/median of the generated sequences we observe a significant difference.

# %%
print('mean:')
display(df_results.mean())
print()
print('median:')
display(df_results.median())
# Out:
# mean:
# rewards (before)    0.211196
# rewards (after)     3.068743
# dtype: float64
# median:
# rewards (before)    0.296938
# rewards (after)     3.997496
# dtype: float64

# %% [markdown]
# ## Save model
# Finally, we save the model to disk for later usage.

# %%
os.makedirs('gpt2-imdb-pos')
gpt2_model.save_pretrained('gpt2-imdb-pos')
gpt2_tokenizer.save_pretrained('gpt2-imdb-pos')
# Out:
# ('gpt2-imdb-pos/vocab.json',
#  'gpt2-imdb-pos/merges.txt',
#  'gpt2-imdb-pos/special_tokens_map.json',
#  'gpt2-imdb-pos/added_tokens.json')
